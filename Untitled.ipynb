# %%
# %pylab inline
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter


tsne = TSNE(n_components=2, init='random', random_state=0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Y = tsne.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-ee95db32172a> in <module>()
# ----> 1 Y = tsne.fit_transform(X)
#
# /Users/dex/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in fit_transform(self, X)
#     517             Embedding of the training data in low-dimensional space.
#     518         """
# --> 519         self._fit(X)
#     520         return self.embedding_
#
# /Users/dex/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _fit(self, X)
#     442         self.training_data_ = X
#     443
# --> 444         P = _joint_probabilities(distances, self.perplexity, self.verbose)
#     445         if self.init == 'pca':
#     446             pca = RandomizedPCA(n_components=self.n_components,
#
# /Users/dex/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _joint_probabilities(distances, desired_perplexity, verbose)
#      49     # the desired perplexity
#      50     conditional_P = _utils._binary_search_perplexity(
# ---> 51         distances, desired_perplexity, verbose)
#      52     P = conditional_P + conditional_P.T
#      53     sum_P = np.maximum(np.sum(P), MACHINE_EPSILON)
#
# _utils.pyx in sklearn.manifold._utils._binary_search_perplexity (sklearn/manifold/_utils.c:2023)()
#
# ValueError: Buffer dtype mismatch, expected 'float_t' but got 'float'

# %%
import pandas as pd

# %%
df = pd.DataFrame(X)

# %%
df.shape
# Out:
# (275, 4096)

# %%
X = np.load("train_set")
y = np.load("train_label")

# %%
df['y']=y

# %%
# Authors: Fabian Pedregosa <fabian.pedregosa@inria.fr>
#          Olivier Grisel <olivier.grisel@ensta.org>
#          Mathieu Blondel <mathieu@mblondel.org>
#          Gael Varoquaux
# License: BSD 3 clause (C) INRIA 2011

print(__doc__)
from time import time

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from sklearn import (manifold, datasets, decomposition, ensemble, lda,
                     random_projection)

digits = datasets.load_digits(n_class=6)
# X = digits.data
# y = digits.target
n_samples, n_features = X.shape
n_neighbors = 30


#----------------------------------------------------------------------
# Scale and visualize the embedding vectors
def plot_embedding(X, title=None):
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    plt.figure()
    ax = plt.subplot(111)
    for i in range(X.shape[0]):
        plt.text(X[i, 0], X[i, 1], str(digits.target[i]),
                 color=plt.cm.Set1(y[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    if hasattr(offsetbox, 'AnnotationBbox'):
        # only print thumbnails with matplotlib > 1.0
        shown_images = np.array([[1., 1.]])  # just something big
        for i in range(digits.data.shape[0]):
            dist = np.sum((X[i] - shown_images) ** 2, 1)
            if np.min(dist) < 4e-3:
                # don't show points that are too close
                continue
            shown_images = np.r_[shown_images, [X[i]]]
            imagebox = offsetbox.AnnotationBbox(
                offsetbox.OffsetImage(digits.images[i], cmap=plt.cm.gray_r),
                X[i])
            ax.add_artist(imagebox)
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)


#----------------------------------------------------------------------
# Plot images of the digits
n_img_per_row = 20
img = np.zeros((10 * n_img_per_row, 10 * n_img_per_row))
for i in range(n_img_per_row):
    ix = 10 * i + 1
    for j in range(n_img_per_row):
        iy = 10 * j + 1
        img[ix:ix + 8, iy:iy + 8] = X[i * n_img_per_row + j].reshape((8, 8))

plt.imshow(img, cmap=plt.cm.binary)
plt.xticks([])
plt.yticks([])
plt.title('A selection from the 64-dimensional digits dataset')


#----------------------------------------------------------------------
# Random 2D projection using a random unitary matrix
print("Computing random projection")
rp = random_projection.SparseRandomProjection(n_components=2, random_state=42)
X_projected = rp.fit_transform(X)
plot_embedding(X_projected, "Random Projection of the digits")
# Out:
# Automatically created module for IPython interactive environment
# Computing random projection

# %%
#----------------------------------------------------------------------
# t-SNE embedding of the digits dataset
print("Computing t-SNE embedding")
tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
t0 = time()
X_tsne = tsne.fit_transform(X)

plot_embedding(X_tsne,
               "t-SNE embedding of the digits (time %.2fs)" %
               (time() - t0))

plt.show()
# Out:
# Computing t-SNE embedding

# %%
digits.keys()
# Out:
# ['images', 'data', 'target_names', 'DESCR', 'target']

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 4, 4, 0])

# %%
digits.data.shape
# Out:
# (1083, 64)

# %%
X[i * n_img_per_row + j].reshape((8, 8))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-592463d2d903> in <module>()
# ----> 1 X[i * n_img_per_row + j].reshape((8, 8))
#
# ValueError: total size of new array must be unchanged

# %%
i=j=0

# %%
>>> from sklearn.datasets import load_digits
>>> digits = load_digits()
>>> print(digits.data.shape)
(1797, 64)
>>> import pylab as pl 
>>> pl.gray() 
>>> pl.matshow(digits.images[0]) 
>>> pl.show()
# Out:
# (1797, 64)

# %%
>>> pl.matshow(digits.images[1])

# %%
digits.images.shape
# Out:
# (1797, 8, 8)

# %%
digits.data.shape
# Out:
# (1797, 64)

# %%
digits.images[0]
# Out:
# array([[  0.,   0.,   5.,  13.,   9.,   1.,   0.,   0.],
#        [  0.,   0.,  13.,  15.,  10.,  15.,   5.,   0.],
#        [  0.,   3.,  15.,   2.,   0.,  11.,   8.,   0.],
#        [  0.,   4.,  12.,   0.,   0.,   8.,   8.,   0.],
#        [  0.,   5.,   8.,   0.,   0.,   9.,   8.,   0.],
#        [  0.,   4.,  11.,   0.,   1.,  12.,   7.,   0.],
#        [  0.,   2.,  14.,   5.,  10.,  12.,   0.,   0.],
#        [  0.,   0.,   6.,  13.,  10.,   0.,   0.,   0.]])

# %%
digits.data[0]
# Out:
# array([  0.,   0.,   5.,  13.,   9.,   1.,   0.,   0.,   0.,   0.,  13.,
#         15.,  10.,  15.,   5.,   0.,   0.,   3.,  15.,   2.,   0.,  11.,
#          8.,   0.,   0.,   4.,  12.,   0.,   0.,   8.,   8.,   0.,   0.,
#          5.,   8.,   0.,   0.,   9.,   8.,   0.,   0.,   4.,  11.,   0.,
#          1.,  12.,   7.,   0.,   0.,   2.,  14.,   5.,  10.,  12.,   0.,
#          0.,   0.,   0.,   6.,  13.,  10.,   0.,   0.,   0.])

# %%
import bunch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-54-c3756ea603da> in <module>()
# ----> 1 import bunch
#
# ImportError: No module named bunch

# %%
# !pip install bunch
# Out:
# You are using pip version 7.0.3, however version 7.1.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting bunch
#   Downloading bunch-1.0.1.tar.gz
# Installing collected packages: bunch
#   Running setup.py install for bunch
# Successfully installed bunch-1.0.1

# %%
import bunch

# %%
# ?bunch

# %%
>>> import numpy as np
>>> from sklearn.manifold import TSNE
>>> X = np.array([[0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
     [0, 0, 0]*1000, 
                  [0, 1, 1]*1000, 
                  [1, 0, 1]*1000, 
                  [1, 1, 1]*1000])
>>> model = TSNE(n_components=2, random_state=0)
>>> model.fit_transform(X)
# Out:
# array([[  9.20907772e+01,   5.66540001e+01],
#        [  1.89549152e+02,   4.87905645e+02],
#        [  1.93368759e+01,   1.08926030e+02],
#        [  6.58115562e+01,  -1.63839791e+02],
#        [ -1.73739328e+01,  -2.47472997e+02],
#        [ -1.24945259e+02,  -6.61494710e+01],
#        [  7.29891629e+02,  -1.41898152e+02],
#        [ -1.03500452e+02,   6.10876982e+01],
#        [  1.49883350e+02,  -3.26438571e+01],
#        [  4.99864058e+02,  -4.33370834e+02],
#        [ -8.75696428e+01,  -3.62628779e+01],
#        [ -3.51364831e+02,  -2.48706072e+02],
#        [ -3.43361290e+02,   2.17552283e+02],
#        [  9.58774244e+01,   9.74416319e+00],
#        [ -1.08001707e+00,  -3.94991148e+01],
#        [  6.34250511e+01,   1.23320009e+02],
#        [  5.15591293e+01,   2.69015882e+01],
#        [ -3.87681492e+01,  -5.68295582e+01],
#        [  1.03058636e+02,  -4.62838222e+02],
#        [ -2.57843040e+02,  -4.64547764e+02],
#        [  7.98937480e+01,  -8.35496385e+01],
#        [ -2.39449579e+02,  -4.64475531e+01],
#        [ -5.00344289e+01,   4.57275930e+01],
#        [ -2.89530995e+01,  -1.21027912e+02],
#        [  2.49082859e+02,  -1.12264876e+02],
#        [  3.48483941e+02,   1.56468547e+02],
#        [ -6.89400907e+01,  -9.11193569e+01],
#        [ -9.20040592e+02,  -1.49669011e+03],
#        [ -1.23397410e+02,  -2.61102656e+02],
#        [  1.82028881e+02,   8.75036079e+01],
#        [ -5.09427746e+01,  -7.37313838e+00],
#        [ -5.43328872e+01,   1.59679255e+02],
#        [  2.43549084e+01,  -9.49183297e+00],
#        [  2.89832453e+02,  -2.84008230e+01],
#        [  1.34447521e+03,   2.22821619e+03],
#        [ -9.88844652e+01,   1.18281034e+02],
#        [  5.19453806e+01,   7.54118199e+01],
#        [ -2.22821826e+01,   1.29664985e+02],
#        [  1.45373522e+02,   5.68510726e+01],
#        [  1.50262328e+01,   5.00176248e+01],
#        [  8.22161500e+02,   6.51739063e+02],
#        [ -1.94437400e+00,  -8.44517089e+01],
#        [  1.06786400e+02,   9.64688921e+01],
#        [ -2.17364159e+01,   8.17483973e+01],
#        [ -1.35022891e+02,  -3.26372404e+00],
#        [  1.10309434e+02,   1.42199121e+02],
#        [ -1.60174011e+01,   1.83435836e+01],
#        [ -1.81660081e+02,  -1.16564000e+01],
#        [ -2.09216451e+02,  -9.83587053e+01],
#        [ -1.24652311e+03,   1.47631373e+02],
#        [  1.46160089e+02,   1.29871671e+01],
#        [ -9.16404442e+01,   1.43453256e+01],
#        [ -6.37060123e+01,   2.93182569e+02],
#        [  1.02853125e+02,   3.20690871e+02],
#        [ -2.63868326e+02,   7.00411282e+01],
#        [ -6.36408067e+01,   8.79707144e+01],
#        [  3.87667579e+01,  -6.32249027e+01],
#        [  6.69709947e+01,  -2.39879612e+01],
#        [ -7.44682335e+02,  -8.58016833e+02],
#        [  1.07964719e+02,  -4.90761242e+01],
#        [  3.60061578e+01,  -1.18093237e+02]])

# %%
X.shape
# Out:
# (61, 3000)
